# %% [markdown]
# # Environment

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# # Data Exploration

# %%
data = pd.read_csv('../data/All.csv')

# %%
data.head()
# Out:
#   Estacion Fecha inicial  Fecha final       PM10  PM2.5
# 0     BOSA    2021-02-28          NaN  21.565217    NaN
# 1     BOSA    2021-02-27          NaN  27.862500    NaN
# 2     BOSA    2021-02-26          NaN  43.891667    NaN
# 3     BOSA    2021-02-25          NaN  29.387500    NaN
# 4     BOSA    2021-02-24          NaN  51.112500    NaN

# %%
data.isnull().sum()
# Out:
# Estacion             0
# Fecha inicial        0
# Fecha final      98432
# PM10             37227
# PM2.5            61205
# dtype: int64

# %%
# Plot the data to see the distribution
sns.displot(data['PM2.5'])

# %%
sns.displot(data['PM10'])

# %%
# Also plot the boxplots to see the outliers

sns.boxplot(data['PM2.5'])
# Out:
# <Axes: >

# %%
sns.boxplot(data['PM10'])
# Out:
# <Axes: >

# %% [markdown]
# # References

# %% [markdown]
# - Sierra Porta, David (2022), “Dataset: Air Quality Bogota”, Mendeley Data, V3, doi: 10.17632/z6wtdbkc5b.3|
